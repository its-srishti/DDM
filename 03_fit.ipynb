# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append(r'C:\Users\ASUS\Documents\DDM')

# %%
from ddm_core import simulate_ddm, fit_ddm
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %%
# Full pipeline test
true_params = dict(v=0.3, a=1.2, z=0.5, t0=0.15)
data = simulate_ddm(**true_params, n_trials=300)
estimated = fit_ddm(data)

print("Parameter  True   Estimated")
print(f"v          {true_params['v']:.2f}   {estimated['v']:.3f}")
print(f"a          {true_params['a']:.2f}   {estimated['a']:.3f}")
print(f"z          {true_params['z']:.2f}   {estimated['z']:.3f}")
print(f"t0         {true_params['t0']:.2f}   {estimated['t0']:.3f}")
# Out:
# Parameter  True   Estimated
# v          0.30   0.312
# a          1.20   1.288
# z          0.50   0.502
# t0         0.15   0.148

# %%
# Full pipeline test
true_params = dict(v=0.3, a=1.2, z=0.7, t0=0.15)
data = simulate_ddm(**true_params, n_trials=300)
estimated = fit_ddm(data)

print("Parameter  True   Estimated")
print(f"v          {true_params['v']:.2f}   {estimated['v']:.3f}")
print(f"a          {true_params['a']:.2f}   {estimated['a']:.3f}")
print(f"z          {true_params['z']:.2f}   {estimated['z']:.3f}")
print(f"t0         {true_params['t0']:.2f}   {estimated['t0']:.3f}")
# Out:
# Parameter  True   Estimated
# v          0.30   0.315
# a          1.20   1.254
# z          0.70   0.689
# t0         0.15   0.149

# %%
# Full pipeline test
true_params = dict(v=0.5, a=1.2, z=0.3, t0=0.15)
data = simulate_ddm(**true_params, n_trials=300)
estimated = fit_ddm(data)

print("Parameter  True   Estimated")
print(f"v          {true_params['v']:.2f}   {estimated['v']:.3f}")
print(f"a          {true_params['a']:.2f}   {estimated['a']:.3f}")
print(f"z          {true_params['z']:.2f}   {estimated['z']:.3f}")
print(f"t0         {true_params['t0']:.2f}   {estimated['t0']:.3f}")
# Out:
# Parameter  True   Estimated
# v          0.50   0.538
# a          1.20   1.242
# z          0.30   0.288
# t0         0.15   0.153

# %%
# Full pipeline test
true_params = dict(v=0.3, a=1.2, z=0.3, t0=0.15)
data = simulate_ddm(**true_params, n_trials=300)
estimated = fit_ddm(data)

print("Parameter  True   Estimated")
print(f"v          {true_params['v']:.2f}   {estimated['v']:.3f}")
print(f"a          {true_params['a']:.2f}   {estimated['a']:.3f}")
print(f"z          {true_params['z']:.2f}   {estimated['z']:.3f}")
print(f"t0         {true_params['t0']:.2f}   {estimated['t0']:.3f}")
# Out:
# Parameter  True   Estimated
# v          0.30   0.380
# a          1.20   1.240
# z          0.30   0.320
# t0         0.15   0.151

# %%
# Full pipeline test
true_params = dict(v=0.7, a=1.2, z=0.7, t0=0.15)
data = simulate_ddm(**true_params, n_trials=300)
estimated = fit_ddm(data)

print("Parameter  True   Estimated")
print(f"v          {true_params['v']:.2f}   {estimated['v']:.3f}")
print(f"a          {true_params['a']:.2f}   {estimated['a']:.3f}")
print(f"z          {true_params['z']:.2f}   {estimated['z']:.3f}")
print(f"t0         {true_params['t0']:.2f}   {estimated['t0']:.3f}")
# Out:
# Parameter  True   Estimated
# v          0.70   0.726
# a          1.20   1.281
# z          0.70   0.694
# t0         0.15   0.147

# %%
true_params_2 = {'v': 0.3, 'a': 1.2, 'z': 0.7, 't0': 0.15}
data_2 = simulate_ddm(**true_params_2, n_trials=500)
your_estimates_2 = fit_ddm(data_2)
print("Your MLE estimates:")
print(f" v={your_estimates_2['v']:.3f}  "
      f" a={your_estimates_2['a']:.3f}  "
      f" z={your_estimates_2['z']:.3f}  "
      f" t0={your_estimates_2['t0']:.3f}")
# Out:
# Your MLE estimates:
#  v=0.316   a=1.288   z=0.697   t0=0.148

# %%
true_params_2 = {'v': 0.3, 'a': 1.2, 'z': 0.3, 't0': 0.15}
data_2 = simulate_ddm(**true_params_2, n_trials=300)
your_estimates_2 = fit_ddm(data_2)
print("Your MLE estimates:")
print(f" v={your_estimates_2['v']:.3f}  "
      f" a={your_estimates_2['a']:.3f}  "
      f" z={your_estimates_2['z']:.3f}  "
      f" t0={your_estimates_2['t0']:.3f}")
# Out:
# Your MLE estimates:
#  v=0.338   a=1.263   z=0.312   t0=0.150

# %%
true_params_2 = {'v': 0.7, 'a': 1.2, 'z': 0.7, 't0': 0.15}
data_2 = simulate_ddm(**true_params_2, n_trials=300)
your_estimates_2 = fit_ddm(data_2)
print("Your MLE estimates:")
print(f" v={your_estimates_2['v']:.3f}  "
      f" a={your_estimates_2['a']:.3f}  "
      f" z={your_estimates_2['z']:.3f}  "
      f" t0={your_estimates_2['t0']:.3f}")
# Out:
# Your MLE estimates:
#  v=0.795   a=1.241   z=0.684   t0=0.142
